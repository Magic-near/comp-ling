# %%
import re
import json

# %%
with open('corpus.json', 'r') as f:
    data = json.loads(f.readline())

# %%
for post in range(5):
    print(data[str(post)]['post_text'])
    print('')
    print('**************************************************************************')
    print('')
# Out:
# Розыгрыш билетов до 02.03 | #artpokaz
#
# Разыгрываем три пары билетов на специальные показы культового фильма «Большой Лебовски»! В марте вернём на большой экран один из главных фильмов братьев Коэн, который показываем по предложению наших зрителей.
# А победитель из Петербурга получит плакат А3 от наших друзей [club77590484|АК Галерея] (автор плаката: [id40334133|Сергей Баюков], лимитированный тираж, настоящее сокровище. Будет задавать тон всей комнате😉)!
#
# Условия розыгрыша:
# 1. Подписывайтесь на паблик проекта, если ещё не с нами.
# 2. Сделайте репост этой записи к себе на стену. Возможно, ваши друзья скажут вам спасибо!
# 3. В комментариях напишите название своего любимого фильма братьев Коэн. Если вы ещё не смотрели Коэнов или сложно выбрать — так и напишите! Возможно, после этого сеанса ваша жизнь изменится).
# 4. Победителя, из числа репостнувших запись, определим через приложение-рандомайзер. Итоги подведём вечером 2-го марта!
#
# Показы «Большого Лебовски» пройдут на английском языке с русскими субтитрами:
#
# 5 марта, 19:00,
# 13 марта, 21:00,
# кц «Родина» (Петербург);
#
# 6 марта, 17:30,
# 13 марта, 19:00,
# кт «Октябрь» (Москва).
#
# Для тех, кто не любит ждать — билеты на сайте: https://vk.cc/bYYqVJ
#
# Подписка на рассылку о следующих розыгрышах: https://vk.cc/88yW4Y
#
# **************************************************************************
#
# «Мое первое „кинопотрясение“ случилось, когда я увидел документальный фильм „Зов дикой природы“. Это была лента о джунглях, о дикой природе. Второй фильм — „Пеппи Длинный-чулок“ — нельзя назвать настоящим потрясением, но он мне очень понравился. А теперь мой любимый фильм — „Успеть до полуночи“ Мартина Бреста с Робертом де Ниро. Имя режиссера я дал своему персонажу в „Достучаться до небес“. Для меня «Успеть до полуночи» — идеальный фильм в своем жанре» — Тиль Швайгер
#
# Показы «Достучаться до небес» пройдут на немецком с русскими субтитрами:
#
# 20 марта,
# 19:00 — кц «Родина» (Петербург);
# 19:30 — кт «Москино Космос» (Москва).
#
# **************************************************************************
#
# Режиссёр Салли Поттер адаптировала роман Вирджинии Вулф и визуализировала историю, используя кинематографический язык в 1992 году. Переосмыслив роман и изменив конец, перенеся его в сегодняшний день, режиссёр показала межпоколенческий феминистский диалог, уделив особое внимание использованию жестов, иронической игре в жанре драмы и костюмам разных исторических периодов.
#
# Любопытно, что у Вирджинии Вулф есть эссе «Кинематограф», опубликованное в 1926 году. В одном из эссе Вулф поднимает вопрос о кинематографической адаптации литературных романов, скептически заявляя о том, что «альянс литературы и кино противоестественен». Для писательницы сила и страсть письменного языка не могли быть адекватно переведены в кинематограф, на большой экран.
#
# «С одной стороны, кино паразитирует на литературе, используя ее. Романы и рассказы легко переносятся на экран, словно только для этого они и были написаны. Словно никакая «внутренняя работа» литературы не нужна, а ее собственные приемы и ее язык ничтожны по сравнению с тем, что предлагает кино. С другой стороны, сама литература просится быть экранизированной, хочет избавиться от той аристократической тонкости, которая замкнула ее на самой себе, превратив писателей и читателей в крайне ограниченное узкое сообщество снобов — литературное сообщество».
#
# Но, несмотря на это, Вирджиния Вулф также верила в потенциал кино: «если большая часть нашего мышления и чувств связана со зрением, какой-то остаток визуальных эмоций, неподвластный литературе, еще ждут в кино. Это будет нечто абстрактное, развивающееся в такт с сознательным и тщательно управляемым художественным творчеством — то, что прибегает к содействию слов и музыки лишь по мелочам, чтобы сделать себя понятным — возможно, именно из таких движений и абстракций со временем будут складываться кинокартины».
#
# Вопрос о том, понравилась бы Вирджинии Вулф экранизация «Орландо» с Тильдой Суинтон остаётся очень интересным, а лично получить необычный опыт просмотра такого кино приглашаем 8 марта в Петербурге и Москве!
#
# Билеты можно купить тут: https://vk.cc/bYvJqg
#
# **************************************************************************
#
# «Фарго» нашел отражение в фильме Коэнов «Большой Лебовски». Главному герою ленты Чуваку предстоит выпутаться из неприятностей. Однако он в основном только ухудшает своё положение. В то же самое время его друг, Донни в исполнении Стива Бушеми, часто оказывается «не в теме».
# Основание, по которому ему стабильно рекомендуют «умолкнуть», кроется в том, что в «Фарго» (что был предыдущим фильмом Коэнов) персонаж Бушеми болтал без умолку.
#
# Фильм братьев Коэн «Фарго» смотрим завтра, в 4К формате в «Октябре»!
#
# **************************************************************************
#
# #хочупосмотреть@artpokaz
#
# Бронкская история / A Bronx Tale (1993)
# Режиссер: Роберт Де Ниро
#
# Король бронкской мафии Сонни убил человека. Просто так. Из-за места на парковке. Среди бела дня вытащил пистолет и несколько раз выстрелил. Полиция узнала, что свидетелем преступления был 9-летний Калоджеро, и допросила мальчика. Но Калоджеро не выдал Сонни. Так началась их дружба. И когда Калоджеро вырос, он не просто стал свидетелем других кровавых деяний своего босса, но и сам оказался на краю пропасти.
#
# **************************************************************************

# %%
pattern = r'\n'
for post in data:
    data[post]['post_text'] = re.sub(pattern, ' ', data[post]['post_text'])

# %%
pattern = r'#\w+@\w+'
for post in data:
    data[post]['post_text'] = re.sub(pattern, '', data[post]['post_text'])

# %%
pattern = r'#\w+'
for post in data:
    data[post]['post_text'] = re.sub(pattern, '', data[post]['post_text'])

# %%
pattern = r'http\S+'
for post in data:
    data[post]['post_text'] = re.sub(pattern, '', data[post]['post_text'], flags=re.MULTILINE)

# %%
pattern = r'[^a-zA-Zа-яёА-ЯЁ\s\d!"#$%&/\\\\\'\(\)\*\+,\-\.:;<=>\?@\[\]^_`{|}~]+'
for post in data:
    data[post]['post_text'] = re.sub(pattern, '', data[post]['post_text'])

# %%
pattern = r'id\d+'
for post in data:
    data[post]['post_text'] = re.sub(pattern, '', data[post]['post_text'])

# %%
pattern = r'club\d+'
for post in data:
    data[post]['post_text'] = re.sub(pattern, '', data[post]['post_text'])

# %%
pattern = r'\|'
for post in data:
    data[post]['post_text'] = re.sub(pattern, '', data[post]['post_text'])

# %%
pattern = r'\s+'
for post in data:
    data[post]['post_text'] = re.sub(pattern, ' ', data[post]['post_text'])

# %%
for post in range(5):
    print(data[str(post)]['post_text'])
    print('')
    print('**************************************************************************')
    print('')
# Out:
# Розыгрыш билетов до 02.03 Разыгрываем три пары билетов на специальные показы культового фильма Большой Лебовски! В марте вернём на большой экран один из главных фильмов братьев Коэн, который показываем по предложению наших зрителей. А победитель из Петербурга получит плакат А3 от наших друзей [АК Галерея] (автор плаката: [Сергей Баюков], лимитированный тираж, настоящее сокровище. Будет задавать тон всей комнате)! Условия розыгрыша: 1. Подписывайтесь на паблик проекта, если ещё не с нами. 2. Сделайте репост этой записи к себе на стену. Возможно, ваши друзья скажут вам спасибо! 3. В комментариях напишите название своего любимого фильма братьев Коэн. Если вы ещё не смотрели Коэнов или сложно выбрать так и напишите! Возможно, после этого сеанса ваша жизнь изменится). 4. Победителя, из числа репостнувших запись, определим через приложение-рандомайзер. Итоги подведём вечером 2-го марта! Показы Большого Лебовски пройдут на английском языке с русскими субтитрами: 5 марта, 19:00, 13 марта, 21:00, кц Родина (Петербург); 6 марта, 17:30, 13 марта, 19:00, кт Октябрь (Москва). Для тех, кто не любит ждать билеты на сайте: Подписка на рассылку о следующих розыгрышах:
